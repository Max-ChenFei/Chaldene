# %% [markdown]
# ## Hello, this is a Markdown Cell

# %%
print('Hello, this is a code cell')
# Out:
# Hello, this is a code cell

# %% [raw]
# {"last_node_id":7,"last_link_id":4,"nodes":[{"id":6,"type":"image/Gaussian2DFilter","pos":[274.44582471996654,102.91954071011567],"size":[180,50],"flags":{},"order":1,"mode":0,"inputs":[{"name":"input","type":"numpy.ndarray","link":3,"slot_index":0},{"name":"sigma","type":"number","link":null}],"outputs":[{"name":"output","type":"numpy.ndarray","links":[4],"slot_index":0}],"properties":{"sigma":1}},{"id":7,"type":"image/imshow","pos":[520.4458247199664,107.91954071011554],"size":[140,50],"flags":{},"order":2,"mode":0,"inputs":[{"name":"image","type":"numpy.ndarray","link":4}],"properties":{"cmap":"plt.cm.gray"}},{"id":5,"type":"image/imread","pos":[116.69528357750255,129.29592789855212],"size":[140,50],"flags":{"collapsed":true},"order":0,"mode":0,"outputs":[{"name":"image","type":"numpy.ndarray","links":[3]}],"properties":{"value":"Lenna.png"}}],"links":[[3,5,0,6,0,"numpy.ndarray"],[4,6,0,7,0,"numpy.ndarray"]],"groups":[{"title":"Gaussian Filter","bounding":[106,50,566,114],"color":"#3f789e"}],"config":{},"extra":{},"version":0.4}
